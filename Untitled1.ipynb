# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('banana_quality.csv')

# %%
data.loc[(data['Sweetness'] > 0.0) & (data['Size'] < 0.0)]
# Out:
#           Size    Weight  Sweetness  Softness  HarvestTime  Ripeness  \
# 0    -1.924968  0.468078   3.077832 -1.472177     0.294799  2.435570
# 1    -2.409751  0.486870   0.346921 -2.495099    -0.892213  2.067549
# 2    -0.357607  1.483176   1.568452 -2.645145    -0.647267  3.090643
# 3    -0.868524  1.566201   1.889605 -1.273761    -1.006278  1.873001
# 5    -2.807722  1.138136   3.447627 -1.713302    -2.220912  2.079410
# ...        ...       ...        ...       ...          ...       ...
# 7983 -3.681090  1.508791   0.406200  1.461839     1.541319 -0.994524
# 7991 -4.559045 -0.449785   1.895221  2.126339    -4.577347  2.585295
# 7992 -3.901210  0.364839   2.004397  1.809546    -1.106952 -1.586317
# 7995 -6.414403  0.723565   1.134953  2.952763     0.297928 -0.156946
# 7999 -2.660879 -2.044666   0.159026  1.499706    -1.581856 -1.605859
#
#        Acidity  Quality
# 0     0.271290      1.0
# 1     0.307325      1.0
# 2     1.427322      1.0
# 3     0.477862      1.0
# ...

# %%
sweetness_arr = data.iloc[:,2]
np.mean(sweetness_arr)
# Out:
# -0.7702241042843923

# %%
data.iloc[1, 3]
# Out:
# -2.4950993

# %%
sw = data.iloc[1]
sw
# Out:
# Size          -2.409751
# Weight         0.486870
# Sweetness      0.346921
# Softness      -2.495099
# HarvestTime   -0.892213
# Ripeness       2.067549
# Acidity        0.307325
# Quality        1.000000
# Name: 1, dtype: float64

# %%
sweetweight = data.loc[:, ['Sweetness', 'Weight']]

# %%
plt.plot(data.loc[:, ['Sweetness']], data.loc[:, ['Size']])

# %%
data['Sweetness'].describe()
# Out:
# count    8000.000000
# mean       -0.770224
# std         1.948455
# min        -6.434022
# 25%        -2.107329
# 50%        -1.020673
# 75%         0.311048
# max         7.539374
# Name: Sweetness, dtype: float64
